# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
# %matplotlib inline

# %%
paths = glob.glob("./kfz_csv/*.csv")

# %%
dfs = []
for path in paths:
    year = int(path.replace("\\", "/").split("/")[-1].strip(".csv"))
    print(year)
    land = ""
    rb = ""
    data = []
    ofile = open(path,"r")
    header = ofile.readline()
    for line in ofile:
        if line[0].isdigit():
            data.append([year,land, rb] + line.replace("\n","").split(";"))
        elif line.startswith("RB"):
            rb = line.split(" ")[1].replace("\n","").split(";")[0]
        else:
            land = line.replace("\n","").split(";")[0]
    ofile.close()

    df = pd.DataFrame(data, columns = ["year","land", "rb"] + header.replace("\n","").split(";"))
    dfs.append(df)
# Out:
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019

# %%
df = pd.concat(dfs)

# %%
df
# Out:
#      year                land        rb                       Stadt Insgesamt  \
# 0    2012  SCHLESWIG-HOLSTEIN                01001  FLENSBURG,STADT     39433
# 1    2012  SCHLESWIG-HOLSTEIN                     01002  KIEL,STADT     99724
# 2    2012  SCHLESWIG-HOLSTEIN                  01003  LUEBECK,STADT     89654
# 3    2012  SCHLESWIG-HOLSTEIN              01004  NEUMUENSTER,STADT     37974
# 4    2012  SCHLESWIG-HOLSTEIN                   01051  DITHMARSCHEN     72836
# ..    ...                 ...       ...                         ...       ...
# 395  2019         THUERINGEN   ZUSAMMEN  16073 SAALFELD-RUDOLSTADT     60.204
# 396  2019         THUERINGEN   ZUSAMMEN  16074 SAALE-HOLZLANDKREIS     49.320
# 397  2019         THUERINGEN   ZUSAMMEN     16075 SAALE-ORLA-KREIS     50.304
# 398  2019         THUERINGEN   ZUSAMMEN                16076 GREIZ     60.390
# 399  2019         THUERINGEN   ZUSAMMEN     16077 ALTENBURGER LAND     51.330
#
#      Benzin  Diesel Gas (einschl. bivalent) Hybrid Elektro  ... Euro 5 Euro 6  \
# 0     26375   12601                     448                 ...   5294      9
# 1     71185   27538                     986                 ...  13421     30
# 2     65879   22799                    1133                 ...  10900     30
# 3     27051   10435                     604                 ...   4441      9
# 4     48921   23173                     775                 ...   6780     21
# ..      ...     ...                     ...    ...     ...  ...    ...    ...
# 395  41.610  17.795                                         ...
# 396  33.522  14.962                                         ...
# 397  33.773  15.944                                         ...
# 398  41.612  17.927                                         ...
# 399  38.057  12.601                                         ...
#
#     Sonstige2 Euro 1 2 Euro 2 2 Euro 3 2 Euro 4 2 Euro 5 2 Euro 6 2 Sonstige3
# 0         187      233     1667     3239     4692     2541        9        97
# 1         836      679     3857     6995     9385     5991       30       427
# 2         646      551     3147     5919     7969     4727       30       307
# 3         165      204     1439     2791     3876     1960        9        71
# 4         518      539     4421     6876     8004     2912       21       253
# ..        ...      ...      ...      ...      ...      ...      ...       ...
# 395
# 396
# 397
# 398
# 399
#
# [3205 rows x 25 columns]

# %%
df["Insgesamt"].head(5)
# Out:
# 0    39433
# 1    99724
# 2    89654
# 3    37974
# 4    72836
# Name: Insgesamt, dtype: object

# %%
df["land"].unique()
# Out:
# array(['SCHLESWIG-HOLSTEIN', 'HAMBURG', 'NIEDERSACHSEN', 'BREMEN',
#        'NORDRHEIN-WESTFALEN', 'HESSEN', 'RHEINLAND-PFALZ',
#        'BADEN-WUERTTEMBERG', 'BAYERN', 'SAARLAND', 'BERLIN',
#        'BRANDENBURG', 'MECKLENBURG-VORPOMMERN', 'SACHSEN',
#        'SACHSEN-ANHALT', 'THUERINGEN', 'BERLIN ', 'BRANDENBURG ',
#        'BREMEN ', 'HAMBURG ', 'HESSEN ', 'MECKLENBURG-VORPOMMERN ',
#        'NIEDERSACHSEN ', 'NORDRHEIN-WESTFALEN ', 'RHEINLAND-PFALZ ',
#        'SAARLAND ', 'SACHSEN ', 'SACHSEN-ANHALT ', 'SCHLESWIG-HOLSTEIN ',
#        'THUERINGEN '], dtype=object)

# %%
df["land"] = df["land"].str.strip(" ")

# %%
df[df["land"]=="SACHSEN-ANHALT"]
# Out:
#      year            land        rb                          Stadt Insgesamt  \
# 364  2012  SACHSEN-ANHALT  ZUSAMMEN    15001  DESSAU-ROSSLAU,STADT     42134
# 365  2012  SACHSEN-ANHALT  ZUSAMMEN     15002  HALLE (SAALE),STADT     89588
# 366  2012  SACHSEN-ANHALT  ZUSAMMEN        15003  MAGDEBURG, STADT    103059
# 367  2012  SACHSEN-ANHALT  ZUSAMMEN  15081  ALTMARKKREIS SALZWEDEL     50285
# 368  2012  SACHSEN-ANHALT  ZUSAMMEN       15082  ANHALT-BITTERFELD     93368
# ..    ...             ...       ...                            ...       ...
# 357  2019  SACHSEN-ANHALT  ZUSAMMEN       15087 MANSFELD-SUEDHARZ     79.807
# 358  2019  SACHSEN-ANHALT  ZUSAMMEN              15088 SAALEKREIS    113.461
# 359  2019  SACHSEN-ANHALT  ZUSAMMEN           15089 SALZLANDKREIS    105.119
# 360  2019  SACHSEN-ANHALT  ZUSAMMEN                 15090 STENDAL     63.397
# 361  2019  SACHSEN-ANHALT  ZUSAMMEN              15091 WITTENBERG     75.207
#
#      Benzin  Diesel Gas (einschl. bivalent) Hybrid Elektro  ... Euro 5 Euro 6  \
# 364   33850    7632                     700                 ...   5123      9
# 365   71564   16641                    1361                 ...  12078     28
# 366   80614   21249                    1212                 ...  14085     41
# 367   36980   12719                     575                 ...   4425      5
# 368   74688   17802                     854                 ...  10121     10
# ..      ...     ...                     ...    ...     ...  ...    ...    ...
# 357  56.375  22.499                                         ...
# 358  80.909  30.686                                         ...
# 359  76.090  27.397                                         ...
# 360  41.547  20.991                                         ...
# 361  54.653  19.383                                         ...
#
#     Sonstige2 Euro 1 2 Euro 2 2 Euro 3 2 Euro 4 2 Euro 5 2 Euro 6 2 Sonstige3
# 364     41887       88      699     2096     3120     1547        9        49
# 365     88978      162     1290     4162     6953     3912       28        73
# 366    101278      220     1744     5209     8311     5507       41       148
# 367     49789      195     1840     3793     4907     1816        5       116
# 368     92655      212     1761     5000     7362     3315       10        83
# ..        ...      ...      ...      ...      ...      ...      ...       ...
# 357
# 358
# 359
# 360
# 361
#
# [112 rows x 25 columns]

# %% [markdown]
# #### Turn columns to numeric values
# * remove '.' so it can be read as float

# %%
df.drop(axis=1, columns = header.replace("\n","").split(";")[4:], inplace=True)

# %%
df[["Insgesamt", "Benzin", "Diesel"]].describe()
# Out:
#        Insgesamt  Benzin  Diesel
# count       3205    3205    3205
# unique      3186    3183    3166
# top        79504  31.504  16.221
# freq           2       2       2

# %%
#####

for head in header.replace("\n","").split(";")[1:4]:
    df[head] = pd.to_numeric(df[head].str.replace(".", ""))

# %%
df["Insgesamt"]
# Out:
# 0      39433
# 1      99724
# 2      89654
# 3      37974
# 4      72836
#        ...
# 395    60204
# 396    49320
# 397    50304
# 398    60390
# 399    51330
# Name: Insgesamt, Length: 3205, dtype: int64

# %% [markdown]
# * split "Stadt" column into "kennzahl" and "ort"
# * by splitting each row by " " (space)
# * add as new columns

# %%
def splits(val):
    return val[:5]
    
df["kennzahl"] = df["Stadt"].apply(splits)

# %%
def splits2(val):
    return val[5:].strip(" ")
    
df["ort"] = df["Stadt"].apply(splits2)

# %%
df["kennzahl"]
# Out:
# 0      01001
# 1      01002
# 2      01003
# 3      01004
# 4      01051
#        ...
# 395    16073
# 396    16074
# 397    16075
# 398    16076
# 399    16077
# Name: kennzahl, Length: 3205, dtype: object

# %%
df["ort"]
# Out:
# 0          FLENSBURG,STADT
# 1               KIEL,STADT
# 2            LUEBECK,STADT
# 3        NEUMUENSTER,STADT
# 4             DITHMARSCHEN
#               ...
# 395    SAALFELD-RUDOLSTADT
# 396    SAALE-HOLZLANDKREIS
# 397       SAALE-ORLA-KREIS
# 398                  GREIZ
# 399       ALTENBURGER LAND
# Name: ort, Length: 3205, dtype: object

# %%
df
# Out:
#      year                land        rb                       Stadt  \
# 0    2012  SCHLESWIG-HOLSTEIN                01001  FLENSBURG,STADT
# 1    2012  SCHLESWIG-HOLSTEIN                     01002  KIEL,STADT
# 2    2012  SCHLESWIG-HOLSTEIN                  01003  LUEBECK,STADT
# 3    2012  SCHLESWIG-HOLSTEIN              01004  NEUMUENSTER,STADT
# 4    2012  SCHLESWIG-HOLSTEIN                   01051  DITHMARSCHEN
# ..    ...                 ...       ...                         ...
# 395  2019          THUERINGEN  ZUSAMMEN  16073 SAALFELD-RUDOLSTADT
# 396  2019          THUERINGEN  ZUSAMMEN  16074 SAALE-HOLZLANDKREIS
# 397  2019          THUERINGEN  ZUSAMMEN     16075 SAALE-ORLA-KREIS
# 398  2019          THUERINGEN  ZUSAMMEN                16076 GREIZ
# 399  2019          THUERINGEN  ZUSAMMEN     16077 ALTENBURGER LAND
#
#      Insgesamt  Benzin  Diesel kennzahl                  ort
# 0        39433   26375   12601    01001      FLENSBURG,STADT
# 1        99724   71185   27538    01002           KIEL,STADT
# 2        89654   65879   22799    01003        LUEBECK,STADT
# 3        37974   27051   10435    01004    NEUMUENSTER,STADT
# 4        72836   48921   23173    01051         DITHMARSCHEN
# ..         ...     ...     ...      ...                  ...
# 395      60204   41610   17795    16073  SAALFELD-RUDOLSTADT
# 396      49320   33522   14962    16074  SAALE-HOLZLANDKREIS
# 397      50304   33773   15944    16075     SAALE-ORLA-KREIS
# 398      60390   41612   17927    16076                GREIZ
# 399      51330   38057   12601    16077     ALTENBURGER LAND
#
# [3205 rows x 9 columns]

# %%
df["ort"]
# Out:
# 0          FLENSBURG,STADT
# 1               KIEL,STADT
# 2            LUEBECK,STADT
# 3        NEUMUENSTER,STADT
# 4             DITHMARSCHEN
#               ...
# 395    SAALFELD-RUDOLSTADT
# 396    SAALE-HOLZLANDKREIS
# 397       SAALE-ORLA-KREIS
# 398                  GREIZ
# 399       ALTENBURGER LAND
# Name: ort, Length: 3205, dtype: object

# %% [markdown]
# #### Load sticktoff dataset

# %%
stickstoff = pd.read_pickle("stickstoff_daten.pkl")

# %%
stickstoff
# Out:
#            bundesland  jahr    station              name  \
# 0         BRANDENBURG  2002  'DEBB001'  BURG (SPREEWALD)
# 1         BRANDENBURG  2002  'DEBB006'       COTTBUS-SÜD
# 2         BRANDENBURG  2002  'DEBB009'             FORST
# 3         BRANDENBURG  2002  'DEBB021'   POTSDAM-ZENTRUM
# 4         BRANDENBURG  2002  'DEBB024'      SENFTENBERG
# ...               ...   ...        ...               ...
# 8681  UMWELTBUNDESAMT  2019    DEUB004      SCHAUINSLAND
# 8682  UMWELTBUNDESAMT  2019    DEUB029          SCHMÜCKE
# 8683  UMWELTBUNDESAMT  2019    DEUB005           WALDHOF
# 8684  UMWELTBUNDESAMT  2019    DEUB001        WESTERLAND
# 8685  UMWELTBUNDESAMT  2019    DEUB028            ZINGST
#
#                umgebungstyp emissionstyp  jahresmittel maxstundenwert  \
# 0     vorstädtisches Gebiet  Hintergrund          10.0             69
# 1        städtisches Gebiet  Hintergrund          19.0            107
# 2     vorstädtisches Gebiet  Hintergrund          16.0             83
# 3        städtisches Gebiet  Hintergrund          21.0            111
# 4        städtisches Gebiet  Hintergrund          19.0            113
# ...                     ...          ...           ...            ...
# 8681      ländlich regional  Hintergrund           2.0              0
# 8682        ländlich Gebiet  Hintergrund           3.0              0
# 8683        ländlich Gebiet  Hintergrund           7.0              0
# 8684        ländlich Gebiet  Hintergrund           5.0              0
# 8685        ländlich Gebiet  Hintergrund           5.0              0
#
#      umgebungstyp_grob
# 0         vorstädtisch
# 1            städtisch
# 2         vorstädtisch
# 3            städtisch
# 4            städtisch
# ...                ...
# 8681          ländlich
# 8682          ländlich
# 8683          ländlich
# 8684          ländlich
# 8685          ländlich
#
# [8685 rows x 9 columns]

# %% [markdown]
# * get only first "word" from sticksplit.name and kraftsplit.ort
# * for potential merging
# * try to split by ' ', '-', '/', ','

# %%
sticksplit = stickstoff["name"].str.split(" ").str[0].str.split("-").str[0].str.split("/").str[0].str.split(",").str[0]

# %%
kraftsplit = df["ort"].str.split(" ").str[0].str.split("-").str[0].str.split("/").str[0].str.split(",").str[0]

# %% [markdown]
# * try to match the new series objects sticksplit and kraftsplit
# * count matches and non matches

# %%
match = 0
no_match = 0
count = 0

isin = False
for index, row in sticksplit.iteritems():
    isin = False
    for index2, row2 in kraftsplit.iteritems():
        if row == row2:
            isin = True
            #print(row, row2)
    if isin:
        match+=1
        count += 1
    else:
        no_match +=1

# %%
match
# Out:
# 4344

# %%
no_match
# Out:
# 4341

# %%
sticksplit
# Out:
# 0               BURG
# 1            COTTBUS
# 2              FORST
# 3            POTSDAM
# 4        SENFTENBERG
#             ...
# 8681    SCHAUINSLAND
# 8682        SCHMÜCKE
# 8683         WALDHOF
# 8684      WESTERLAND
# 8685          ZINGST
# Name: name, Length: 8685, dtype: object

# %%
kraftsplit
# Out:
# 0         FLENSBURG
# 1              KIEL
# 2           LUEBECK
# 3       NEUMUENSTER
# 4      DITHMARSCHEN
#            ...
# 395        SAALFELD
# 396           SAALE
# 397           SAALE
# 398           GREIZ
# 399     ALTENBURGER
# Name: ort, Length: 3205, dtype: object

# %% [markdown]
# # Insert proper year variable (im moment nur ein Jahr/File)

# %%
df
# Out:
#      year                land        rb                       Stadt  \
# 0    2012  SCHLESWIG-HOLSTEIN                01001  FLENSBURG,STADT
# 1    2012  SCHLESWIG-HOLSTEIN                     01002  KIEL,STADT
# 2    2012  SCHLESWIG-HOLSTEIN                  01003  LUEBECK,STADT
# 3    2012  SCHLESWIG-HOLSTEIN              01004  NEUMUENSTER,STADT
# 4    2012  SCHLESWIG-HOLSTEIN                   01051  DITHMARSCHEN
# ..    ...                 ...       ...                         ...
# 395  2019          THUERINGEN  ZUSAMMEN  16073 SAALFELD-RUDOLSTADT
# 396  2019          THUERINGEN  ZUSAMMEN  16074 SAALE-HOLZLANDKREIS
# 397  2019          THUERINGEN  ZUSAMMEN     16075 SAALE-ORLA-KREIS
# 398  2019          THUERINGEN  ZUSAMMEN                16076 GREIZ
# 399  2019          THUERINGEN  ZUSAMMEN     16077 ALTENBURGER LAND
#
#      Insgesamt  Benzin  Diesel kennzahl                  ort
# 0        39433   26375   12601    01001      FLENSBURG,STADT
# 1        99724   71185   27538    01002           KIEL,STADT
# 2        89654   65879   22799    01003        LUEBECK,STADT
# 3        37974   27051   10435    01004    NEUMUENSTER,STADT
# 4        72836   48921   23173    01051         DITHMARSCHEN
# ..         ...     ...     ...      ...                  ...
# 395      60204   41610   17795    16073  SAALFELD-RUDOLSTADT
# 396      49320   33522   14962    16074  SAALE-HOLZLANDKREIS
# 397      50304   33773   15944    16075     SAALE-ORLA-KREIS
# 398      60390   41612   17927    16076                GREIZ
# 399      51330   38057   12601    16077     ALTENBURGER LAND
#
# [3205 rows x 9 columns]

# %%
stickstoff
# Out:
#            bundesland  jahr    station              name  \
# 0         BRANDENBURG  2002  'DEBB001'  BURG (SPREEWALD)
# 1         BRANDENBURG  2002  'DEBB006'       COTTBUS-SÜD
# 2         BRANDENBURG  2002  'DEBB009'             FORST
# 3         BRANDENBURG  2002  'DEBB021'   POTSDAM-ZENTRUM
# 4         BRANDENBURG  2002  'DEBB024'      SENFTENBERG
# ...               ...   ...        ...               ...
# 8681  UMWELTBUNDESAMT  2019    DEUB004      SCHAUINSLAND
# 8682  UMWELTBUNDESAMT  2019    DEUB029          SCHMÜCKE
# 8683  UMWELTBUNDESAMT  2019    DEUB005           WALDHOF
# 8684  UMWELTBUNDESAMT  2019    DEUB001        WESTERLAND
# 8685  UMWELTBUNDESAMT  2019    DEUB028            ZINGST
#
#                umgebungstyp emissionstyp  jahresmittel maxstundenwert  \
# 0     vorstädtisches Gebiet  Hintergrund          10.0             69
# 1        städtisches Gebiet  Hintergrund          19.0            107
# 2     vorstädtisches Gebiet  Hintergrund          16.0             83
# 3        städtisches Gebiet  Hintergrund          21.0            111
# 4        städtisches Gebiet  Hintergrund          19.0            113
# ...                     ...          ...           ...            ...
# 8681      ländlich regional  Hintergrund           2.0              0
# 8682        ländlich Gebiet  Hintergrund           3.0              0
# 8683        ländlich Gebiet  Hintergrund           7.0              0
# 8684        ländlich Gebiet  Hintergrund           5.0              0
# 8685        ländlich Gebiet  Hintergrund           5.0              0
#
#      umgebungstyp_grob
# 0         vorstädtisch
# 1            städtisch
# 2         vorstädtisch
# 3            städtisch
# 4            städtisch
# ...                ...
# 8681          ländlich
# 8682          ländlich
# 8683          ländlich
# 8684          ländlich
# 8685          ländlich
#
# [8685 rows x 9 columns]

# %%
stickstoff["split"] = sticksplit
df["split"] = kraftsplit

# %%
df.rename(columns={"land":"bundesland", "year":"jahr"}, inplace=True)
stickstoff["jahr"] = pd.to_numeric(stickstoff["jahr"])

# %%
result = pd.merge(left=stickstoff, right=df, on=["jahr", "bundesland", "split"])

# %%
result.shape
# Out:
# (2523, 17)

# %%
result
# Out:
#               bundesland  jahr  station                             name  \
# 0     BADEN-WUERTTEMBERG  2012  DEBW076                      BADEN-BADEN
# 1     BADEN-WUERTTEMBERG  2012  DEBW046                         BIBERACH
# 2     BADEN-WUERTTEMBERG  2012  DEBW084                         FREIBURG
# 3     BADEN-WUERTTEMBERG  2012  DEBW122  FREIBURG SCHWARZWALDSTRASSE (V)
# 4     BADEN-WUERTTEMBERG  2012  DEBW127   FREIBURG ZÄHRINGER STRASSE (S)
# ...                  ...   ...      ...                              ...
# 2518          THUERINGEN  2019  DETH102        SUHL DR.TH.-NEUBAUER-STR.
# 2519          THUERINGEN  2019  DETH072                SUHL F.-KÖNIG-STR
# 2520          THUERINGEN  2019  DETH101               WEIMAR JENAER STR.
# 2521          THUERINGEN  2019  DETH093             WEIMAR SCHWANSEESTR.
# 2522          THUERINGEN  2019  DETH083               WEIMAR STEUBENSTR.
#
#                umgebungstyp emissionstyp  jahresmittel maxstundenwert  \
# 0     vorstädtisches Gebiet  Hintergrund          15.0              0
# 1     vorstädtisches Gebiet  Hintergrund          19.0              0
# 2        städtisches Gebiet  Hintergrund          19.0              0
# 3        städtisches Gebiet      Verkehr          65.0              0
# 4        städtisches Gebiet      Verkehr          50.0            ---
# ...                     ...          ...           ...            ...
# 2518     städtisches Gebiet      Verkehr          29.0         --- 1)
# 2519     städtisches Gebiet      Verkehr          22.0              0
# 2520     städtisches Gebiet      Verkehr          28.0         --- 1)
# 2521     städtisches Gebiet  Hintergrund          15.0              0
# 2522     städtisches Gebiet      Verkehr          21.0              0
#
#      umgebungstyp_grob     split         rb                           Stadt  \
# 0         vorstädtisch     BADEN  KARLSRUHE        08211  BADEN-BADEN,STADT
# 1         vorstädtisch  BIBERACH  TUEBINGEN                 08426  BIBERACH
# 2            städtisch  FREIBURG   FREIBURG  08311  FREIBURG I.BREISG.STADT
# 3            städtisch  FREIBURG   FREIBURG  08311  FREIBURG I.BREISG.STADT
# 4            städtisch  FREIBURG   FREIBURG  08311  FREIBURG I.BREISG.STADT
# ...                ...       ...        ...                             ...
# 2518         städtisch      SUHL   ZUSAMMEN              16054 SUHL, STADT
# 2519         städtisch      SUHL   ZUSAMMEN              16054 SUHL, STADT
# 2520         städtisch    WEIMAR   ZUSAMMEN            16055 WEIMAR, STADT
# 2521         städtisch    WEIMAR   ZUSAMMEN            16055 WEIMAR, STADT
# 2522         städtisch    WEIMAR   ZUSAMMEN            16055 WEIMAR, STADT
#
#       Insgesamt  Benzin  Diesel kennzahl                      ort
# 0         31179   21411    9555    08211        BADEN-BADEN,STADT
# 1        110593   72949   36744    08426                 BIBERACH
# 2         85591   56824   27764    08311  FREIBURG I.BREISG.STADT
# 3         85591   56824   27764    08311  FREIBURG I.BREISG.STADT
# 4         85591   56824   27764    08311  FREIBURG I.BREISG.STADT
# ...         ...     ...     ...      ...                      ...
# 2518      20424   13866    6174    16054              SUHL, STADT
# 2519      20424   13866    6174    16054              SUHL, STADT
# 2520      29074   19887    8662    16055            WEIMAR, STADT
# 2521      29074   19887    8662    16055            WEIMAR, STADT
# 2522      29074   19887    8662    16055            WEIMAR, STADT
#
# [2523 rows x 17 columns]

# %%
for id, item in df["Stadt"].iteritems():
    if "BERLIN" in item:
        print(item)
# Out:
# 11000  BERLIN
# 11000 BERLIN
# 11000 BERLIN
# 11000 BERLIN
# 11000 BERLIN
# 11000 BERLIN
# 11000 BERLIN
# 11000 BERLIN

# %%
for id, item in df["split"].iteritems():
    if "BERLIN" in item:
        print(item)
# Out:
# BERLIN
# BERLIN
# BERLIN
# BERLIN
# BERLIN
# BERLIN
# BERLIN
# BERLIN

# %%
result.groupby("umgebungstyp")["umgebungstyp"].count()
# Out:
# umgebungstyp
# ländlich Gebiet            13
# ländlich regional          48
# ländlich stadtnah          39
# städtisches Gebiet       2131
# vorstädtisches Gebiet     292
# Name: umgebungstyp, dtype: int64

# %%
result.groupby("emissionstyp")["emissionstyp"].count()
# Out:
# emissionstyp
# Hintergrund    1025
# Industrie       111
# Verkehr        1387
# Name: emissionstyp, dtype: int64

# %%
selection = result[result["emissionstyp"] == "Verkehr"]
result_clean = selection[["jahr","bundesland","split","jahresmittel","Insgesamt"]].copy()
result_clean["dieselanteil"] = selection["Diesel"] / selection["Insgesamt"]

# %%
result_clean
# Out:
#       jahr          bundesland       split  jahresmittel  Insgesamt  \
# 3     2012  BADEN-WUERTTEMBERG    FREIBURG          65.0      85591
# 4     2012  BADEN-WUERTTEMBERG    FREIBURG          50.0      85591
# 6     2012  BADEN-WUERTTEMBERG  HEIDELBERG          51.0      55499
# 7     2012  BADEN-WUERTTEMBERG  HEIDENHEIM          53.0      73503
# 10    2012  BADEN-WUERTTEMBERG   KARLSRUHE          46.0     131995
# ...    ...                 ...         ...           ...        ...
# 2517  2019          THUERINGEN    SAALFELD          28.0      60204
# 2518  2019          THUERINGEN        SUHL          29.0      20424
# 2519  2019          THUERINGEN        SUHL          22.0      20424
# 2520  2019          THUERINGEN      WEIMAR          28.0      29074
# 2522  2019          THUERINGEN      WEIMAR          21.0      29074
#
#       dieselanteil
# 3         0.324380
# 4         0.324380
# 6         0.300348
# 7         0.299321
# 10        0.312035
# ...            ...
# 2517      0.295578
# 2518      0.302291
# 2519      0.302291
# 2520      0.297929
# 2522      0.297929
#
# [1387 rows x 6 columns]

# %%
result_clean["location"] = result_clean["bundesland"] + " " + result_clean["split"]

# %%
result_clean["location"]
# Out:
# 3         BADEN-WUERTTEMBERG FREIBURG
# 4         BADEN-WUERTTEMBERG FREIBURG
# 6       BADEN-WUERTTEMBERG HEIDELBERG
# 7       BADEN-WUERTTEMBERG HEIDENHEIM
# 10       BADEN-WUERTTEMBERG KARLSRUHE
#                     ...
# 2517              THUERINGEN SAALFELD
# 2518                  THUERINGEN SUHL
# 2519                  THUERINGEN SUHL
# 2520                THUERINGEN WEIMAR
# 2522                THUERINGEN WEIMAR
# Name: location, Length: 1387, dtype: object

# %% [markdown]
# * remove all <0 Values

# %%
result_clean = result_clean[result_clean["jahresmittel"] > 0]

# %%
result_clean[result_clean["jahresmittel"] <0]
# Out:
# Empty DataFrame
# Columns: [jahr, bundesland, split, jahresmittel, Insgesamt, dieselanteil, location]
# Index: []

# %%
years = [2012,2013,2014,2015,2016,2017,2018,2019]
year_df = []
for year in years:
    year_df.append(result_clean[result_clean["jahr"] == year])

# %%
sum_no2 = result_clean.groupby("location")[["jahresmittel","Insgesamt", "dieselanteil"]].mean()

# %%
sum_no2
# Out:
#                                jahresmittel      Insgesamt  dieselanteil
# location
# BADEN-WUERTTEMBERG ESSLINGEN      46.500000  322083.750000      0.328483
# BADEN-WUERTTEMBERG FREIBURG       49.153846   88447.384615      0.352220
# BADEN-WUERTTEMBERG HEIDELBERG     42.375000   58094.125000      0.333817
# BADEN-WUERTTEMBERG HEIDENHEIM     45.000000   77546.250000      0.327444
# BADEN-WUERTTEMBERG HEILBRONN      57.714286  143025.928571      0.337812
# ...                                     ...            ...           ...
# THUERINGEN GERA                   34.875000   45148.125000      0.248026
# THUERINGEN JENA                   32.083333   43285.750000      0.281555
# THUERINGEN SAALFELD               28.000000   60204.000000      0.295578
# THUERINGEN SUHL                   31.687500   19632.375000      0.280905
# THUERINGEN WEIMAR                 32.133333   28061.600000      0.276627
#
# [96 rows x 3 columns]

# %%
sum_no2.to_csv("sum_no2.csv")

# %%
sum_no2.plot(x="Insgesamt", y="jahresmittel",kind="scatter") #xlim=(0,350000)

# %%
sum_no2.corr()
# Out:
#               jahresmittel  Insgesamt  dieselanteil
# jahresmittel      1.000000   0.367114      0.203145
# Insgesamt         0.367114   1.000000      0.013738
# dieselanteil      0.203145   0.013738      1.000000

# %%
sum_no2.plot(x="dieselanteil", y="jahresmittel",kind="scatter")

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = sum_no2["Insgesamt"].values.reshape(-1, 1)
train_y = sum_no2["jahresmittel"].values.reshape(-1, 1)
regr.fit (train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[2.12173756e-05]]
# Intercept:  [36.41527569]

# %%
Y_pred = regr.predict(train_x)

# %%
plt.scatter(train_x, train_y)
plt.plot(train_x, Y_pred, color='red')
plt.show()

# %%
from sklearn.metrics import r2_score

#train_x = np.asanyarray(test[['ENGINESIZE']])
#train_y = np.asanyarray(test[['CO2EMISSIONS']])
train_y_ = regr.predict(train_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(train_y_ - train_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((train_y_ - train_y) ** 2))
print("R2-score: %.2f" % r2_score(train_y, train_y_) )
# Out:
# Mean absolute error: 6.21
# Residual sum of squares (MSE): 66.82
# R2-score: 0.13

# %%
regr = linear_model.LinearRegression()
train_x = sum_no2["dieselanteil"].values.reshape(-1, 1)
train_y = sum_no2["jahresmittel"].values.reshape(-1, 1)
regr.fit (train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[37.68801352]]
# Intercept:  [28.31481752]

# %%
Y_pred = regr.predict(train_x) 
plt.scatter(train_x, train_y)
plt.plot(train_x, Y_pred, color='red')
plt.show()

# %%
sum_no2[sum_no2["Insgesamt"] > 400000]
# Out:
#                         jahresmittel     Insgesamt  dieselanteil
# location
# BERLIN BERLIN              43.892857  1.206810e+06      0.251268
# HAMBURG HAMBURG            52.375000  7.592280e+05      0.323915
# NIEDERSACHSEN HANNOVER     46.772727  5.510505e+05      0.292307

# %% [markdown]
# # DROPPED LINES

# %%
sum_no2 = sum_no2[sum_no2["Insgesamt"] < 400000]

# %%
from sklearn.metrics import r2_score

#train_x = np.asanyarray(test[['ENGINESIZE']])
#train_y = np.asanyarray(test[['CO2EMISSIONS']])
train_y_ = regr.predict(train_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(train_y_ - train_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((train_y_ - train_y) ** 2))
print("R2-score: %.2f" % r2_score(train_y, train_y_) )
# Out:
# Mean absolute error: 6.64
# Residual sum of squares (MSE): 74.04
# R2-score: 0.04

# %%
year_df[0]
# Out:
#      jahr          bundesland       split  jahresmittel  Insgesamt  \
# 3    2012  BADEN-WUERTTEMBERG    FREIBURG          65.0      85591
# 4    2012  BADEN-WUERTTEMBERG    FREIBURG          50.0      85591
# 6    2012  BADEN-WUERTTEMBERG  HEIDELBERG          51.0      55499
# 7    2012  BADEN-WUERTTEMBERG  HEIDENHEIM          53.0      73503
# 10   2012  BADEN-WUERTTEMBERG   KARLSRUHE          46.0     131995
# ..    ...                 ...         ...           ...        ...
# 290  2012          THUERINGEN        JENA          38.0      42252
# 293  2012          THUERINGEN        SUHL          42.0      19961
# 294  2012          THUERINGEN        SUHL          28.0      19961
# 295  2012          THUERINGEN      WEIMAR          47.0      27342
# 296  2012          THUERINGEN      WEIMAR          34.0      27342
#
#      dieselanteil                       location
# 3        0.324380    BADEN-WUERTTEMBERG FREIBURG
# 4        0.324380    BADEN-WUERTTEMBERG FREIBURG
# 6        0.300348  BADEN-WUERTTEMBERG HEIDELBERG
# 7        0.299321  BADEN-WUERTTEMBERG HEIDENHEIM
# 10       0.312035   BADEN-WUERTTEMBERG KARLSRUHE
# ..            ...                            ...
# 290      0.249834                THUERINGEN JENA
# 293      0.244978                THUERINGEN SUHL
# 294      0.244978                THUERINGEN SUHL
# 295      0.241204              THUERINGEN WEIMAR
# 296      0.241204              THUERINGEN WEIMAR
#
# [165 rows x 7 columns]

# %%
grouped = []
for x in year_df:
    grouped.append(x.groupby("location")[["jahresmittel","Insgesamt", "dieselanteil"]].mean())

# %%
grouped[0]
# Out:
#                                 jahresmittel  Insgesamt  dieselanteil
# location
# BADEN-WUERTTEMBERG FREIBURG        57.500000    85591.0      0.324380
# BADEN-WUERTTEMBERG HEIDELBERG      51.000000    55499.0      0.300348
# BADEN-WUERTTEMBERG HEIDENHEIM      53.000000    73503.0      0.299321
# BADEN-WUERTTEMBERG KARLSRUHE       46.000000   189694.0      0.294489
# BADEN-WUERTTEMBERG LUDWIGSBURG     61.000000   292479.0      0.277097
# ...                                      ...        ...           ...
# THUERINGEN ERFURT                  39.666667    89335.0      0.244182
# THUERINGEN GERA                    41.000000    44787.0      0.213165
# THUERINGEN JENA                    35.000000    42252.0      0.249834
# THUERINGEN SUHL                    35.000000    19961.0      0.244978
# THUERINGEN WEIMAR                  40.500000    27342.0      0.241204
#
# [81 rows x 3 columns]

# %%
heatmap = pd.DataFrame(index=grouped[0].index)
for id,year in enumerate(years):
    heatmap[str(year)] = grouped[id]["jahresmittel"]

# %%
heatmap
# Out:
#                                      2012  2013  2014  2015       2016  \
# location
# BADEN-WUERTTEMBERG FREIBURG     57.500000  54.5  52.5  48.5  41.000000
# BADEN-WUERTTEMBERG HEIDELBERG   51.000000  46.0  44.0  45.0  42.000000
# BADEN-WUERTTEMBERG HEIDENHEIM   53.000000  50.0  49.0  48.0  44.000000
# BADEN-WUERTTEMBERG KARLSRUHE    46.000000  39.0   NaN   NaN        NaN
# BADEN-WUERTTEMBERG LUDWIGSBURG  61.000000  64.0  61.0  58.0  53.000000
# ...                                   ...   ...   ...   ...        ...
# THUERINGEN ERFURT               39.666667  38.5  37.0  32.0  33.666667
# THUERINGEN GERA                 41.000000  41.5  34.5  34.0  34.500000
# THUERINGEN JENA                 35.000000  35.5  33.0  31.0  31.000000
# THUERINGEN SUHL                 35.000000  34.5  33.5  33.0  32.000000
# THUERINGEN WEIMAR               40.500000  44.0  35.0  31.5  31.000000
#
#                                      2017       2018  2019
# location
# BADEN-WUERTTEMBERG FREIBURG     43.000000  50.000000  36.0
# BADEN-WUERTTEMBERG HEIDELBERG   39.000000  38.000000  34.0
# BADEN-WUERTTEMBERG HEIDENHEIM   41.000000  39.000000  36.0
# BADEN-WUERTTEMBERG KARLSRUHE    39.000000  38.000000  34.0
# BADEN-WUERTTEMBERG LUDWIGSBURG  51.000000  51.000000   NaN
# ...                                   ...        ...   ...
# THUERINGEN ERFURT               31.333333  30.666667  26.0
# THUERINGEN GERA                 32.500000  33.000000  28.0
# THUERINGEN JENA                 31.000000  29.000000  25.0
# THUERINGEN SUHL                 32.000000  28.000000  25.5
# THUERINGEN WEIMAR               28.500000  28.000000  24.5
#
# [81 rows x 8 columns]

# %%
import seaborn as sns

# %%
Index = list(heatmap.index)
Cols = list(heatmap.columns)

# %%
sns.heatmap(heatmap, annot=False)

# %%
#heatmap = heatmap[heatmap["2015"]>0]

# %%
heatmap[heatmap["2015"] < 0]
# Out:
# Empty DataFrame
# Columns: [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
# Index: []

# %%
heatmap = pd.DataFrame(index=grouped[0].index)
for id,year in enumerate(years):
    heatmap[str(year)] = grouped[id]["Insgesamt"]

# %%
sns.heatmap(heatmap, annot=False)

# %%
#from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LassoCV
from sklearn.pipeline import make_pipeline

# %%
lasso_eps = 0.0001
lasso_nalpha=20
lasso_iter=5000

# %%
degree_min = 2
degree_max = 8

# %%
x = sum_no2["Insgesamt"].values.reshape(-1, 1)
y = sum_no2["jahresmittel"].values.reshape(-1, 1)

# %% [markdown]
# * create model of Polynomial features with lasso regression
# * fit models to our data
# * save model error, score and model

# %%
results = []
for degree in range(degree_min,degree_max+1):
    model = make_pipeline(PolynomialFeatures(degree, interaction_only=False), LassoCV(eps=lasso_eps,n_alphas=lasso_nalpha,max_iter=lasso_iter,normalize=True,cv=5))
    model.fit(x,y)
    test_pred = np.array(model.predict(x))
    RMSE=np.sqrt(np.sum(np.square(test_pred-y)))
    test_score = model.score(x,y)
    results.append((model, RMSE, test_score))
# Out:
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84.18473864579755, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.12652026233877, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 299.305433684116, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 460.5772428975929, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 578.1909915624803, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56.86024631890723, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 211.7209918711933, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 603.9888461987252, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 904.8155005491212, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1124.2540687800865, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1287.6391741343991, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96.88506199025733, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91.95382318241718, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 503.05678289252137, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 850.6532037162269, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1108.1912192905306, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.29319012666565, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41.14128389620555, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.08937459457593, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.304064197519892, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 339.4624009727304, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 713.0774026392278, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 987.9837702378916, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1185.8118951059328, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22.218630091599607, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.40238776670867, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.22615905139628, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.886194310971405, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 225.64408192938754, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 514.4623242878554, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47.4395401126194, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 176.60383873304818, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 249.38496048396564, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 327.57910808219503, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 433.0565146006211, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 579.9957051309259, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 771.597805911975, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 112.03735994249973, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 223.32118172110677, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 274.9169148125302, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 372.01747385032513, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 811.9303587387994, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1243.1212684164193, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.457146357696274, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.9497232989738222, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 186.7873675997157, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 637.3761669497032, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1054.4416704953073, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96.4699010248105, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 202.81898341145688, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 278.99268068673655, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 345.48582564160733, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 419.8250703731337, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 516.032492294896, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1731.9737426139081, tolerance: 0.7171579315710889
#   positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.8521434804624732, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51.5093366983524, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 240.60474741064013, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 490.4009592866813, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 708.7363068476568, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1417834996132115, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9469600311081194, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8779525258005378, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.484265843793764, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 158.85970890631506, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 406.83839595878044, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 791.769723100238, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1142.3986171858571, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7213100476174077, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49.08741019477657, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 229.53266665145338, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 558.4386510225161, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 977.9606439035363, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1310.551667942164, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1549.2644902993975, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.904632755166404, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 148.67065764898553, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 393.77232198011916, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 786.2186554695302, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1119.5110822135493, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1313.9566351037738, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.815616834768662, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.275157241497254, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.409461570628082, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36.65943839343936, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134.5337849856419, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 348.1767301189125, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 620.3943299788725, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1570.69256706356, tolerance: 0.7171579315710889
#   positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.378040250940103, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 103.29327484036821, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 238.84820819406264, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 419.87648576648076, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 611.168500303634, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 68.28177801265338, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 269.8178943627063, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 555.0061623103084, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 847.5220424321719, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1108.3173117798224, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.004904162995444, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151.76137749246845, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 390.27794660317386, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 517.8457520372224, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1027.3522809773965, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1328.4209221244384, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1526.6096004999572, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.196768968258311, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 109.49217438373807, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 306.43158171656887, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 435.9724127545958, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 900.6722186308566, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1206.5085904144496, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1408.8622569236686, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.624469417457476, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 209.81028756789647, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 500.2767823183781, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 810.3275635513401, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1659.268146665338, tolerance: 0.7171579315710889
#   positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.1293192095508857, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.473124863922294, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105.81232928168629, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 210.90864780235552, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 335.2997794591083, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 432.02940575667685, tolerance: 0.4250799577153337
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.601726442489962, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 55.201077432886905, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 141.54786783960344, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 289.05401557359755, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 477.1199618054791, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 881.1580581257053, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1166.6715878342206, tolerance: 0.5720600409132304
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.336203931275577, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73.58499225231208, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 80.4687569648695, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 246.1529235259277, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 686.2982534057048, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1021.7700140606753, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1253.487100090671, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1418.2132185704138, tolerance: 0.6480462021818543
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.370479160756531, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47.75211359982359, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.092057751124685, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 157.23858597496974, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 578.5149950985749, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 913.9440649868286, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1148.1975108251677, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1265.6364999061052, tolerance: 0.6213092309781029
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.221971126960852, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18.97210399371761, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 68.54385633359152, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 160.78158795771014, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 330.02248309839933, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 642.0264921103699, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 921.0647278157873, tolerance: 0.5814506926363123
#   tol, rng, random, positive)
# C:\Users\Robin\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1831.3467601580871, tolerance: 0.7171579315710889
#   positive)

# %%
for id,result in enumerate(results):
    print(result[1])
# Out:
# 927.0006409476733
# 943.8469515477809
# 939.3162054216109
# 944.5486863831735
# 949.9500111482988
# 953.7528757992576
# 956.6367160311669

# %%
for id,result in enumerate(results):
    print(result[2])
# Out:
# 0.3126411649476045
# 0.3366878076493217
# 0.33286550328201114
# 0.3463079559768144
# 0.3536584484570334
# 0.3613438372719864
# 0.3702817133393671

# %% [markdown]
# * we see, first model yields the lowest error, but also lowest score
# * todo: check how score is calculated
# * also: want to keep model simple
#
# #### Plot for each power level

# %%
plt.scatter(x, results[0][0].predict(x))
plt.scatter(x,y)
plt.title("Quadratisch")
plt.xlabel("KFZ Insgesamt")
plt.ylabel("Jahresmittel NO2")
# Out:
# Text(0, 0.5, 'Jahresmittel NO2')

# %%
plt.scatter(x, results[1][0].predict(x))
plt.scatter(x,y)
plt.title("Kubisch")
plt.xlabel("KFZ Insgesamt")
plt.ylabel("Jahresmittel NO2")
# Out:
# Text(0, 0.5, 'Jahresmittel NO2')

# %%
plt.scatter(x, results[2][0].predict(x))
plt.scatter(x,y)
plt.title("^4")
plt.xlabel("KFZ Insgesamt")
plt.ylabel("Jahresmittel NO2")
# Out:
# Text(0, 0.5, 'Jahresmittel NO2')

# %%
plt.scatter(x, results[3][0].predict(x))
plt.scatter(x,y)
plt.title("^5")
plt.xlabel("KFZ Insgesamt")
plt.ylabel("Jahresmittel NO2")
# Out:
# Text(0, 0.5, 'Jahresmittel NO2')

# %%
plt.scatter(x, results[4][0].predict(x))
plt.scatter(x,y)
plt.title("^6")
plt.xlabel("KFZ Insgesamt")
plt.ylabel("Jahresmittel NO2")
# Out:
# Text(0, 0.5, 'Jahresmittel NO2')

# %%
plt.scatter(x, results[5][0].predict(x))
plt.scatter(x,y)
plt.title("^7")
plt.xlabel("KFZ Insgesamt")
plt.ylabel("Jahresmittel NO2")
# Out:
# Text(0, 0.5, 'Jahresmittel NO2')

# %%
plt.scatter(x, results[6][0].predict(x))
plt.scatter(x,y)
plt.title("^8")
plt.xlabel("KFZ Insgesamt")
plt.ylabel("Jahresmittel NO2")
# Out:
# Text(0, 0.5, 'Jahresmittel NO2')
